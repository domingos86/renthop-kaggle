# %% [markdown]
# # Task:  Predict the number of inquiries a new listing receives based on the listing’s creation date and other features.
# Doing so will help RentHop better handle fraud control, identify potential listing quality issues, and allow owners and agents to better understand renters’ needs and preferences.
#
#
# # Rules for a Safe legal recidence in NYC
# Bedrooms must be 80 square feet in size and no dimension should be less than 8 feet.
# However, if the apartment has three or more bedrooms, half the bedrooms can have a minimum dimension of 7 feet.
#
# They must have an 8 foot ceiling height. If they are in the basement the ceiling height must be at least 7 feet.
#
# There needs to be at least one window that opens to a street, or a yard, garden, or court.
#
# Bedrooms cannot serve as passage to another room.
#
# # Red Flags for Illegal Apt:
#
# The apartment is in a basement (or less common for NYC, an attic)
#
# No inside plumbing, bathroom, or cooking area
#
# If the bathroom or kitchen are separated. (This could look like a toilet and a shower in different rooms or a fridge and stove in different areas.)
#
# No windows
#
# No secondary exit
#
# You operate on one gas and/or electrical meter with other people
#
# # User questions on Rent Hop
#  how do you know whether the person who posted the listing will get back to you, or if they’re even a real person?
#
#  # What does the hopscore depends at the moment:
#  The quality of the listing (e.g. its completeness, its accuracy)
#
#   The “freshness” of the listing, which refers to how long it’s been on the site and how many times other users have clicked on it.
#
#    The performance of the manager (the person who posted the listing) on our site.
#
#
#  # Points to Note:
#  Unfortunately the apartment rental market (especially in New York) is extremely competitive – often apartments in New York will be rented within hours after a listing appears online.
#
#  A washer or Dryer should be in wet area in any apartment
#
#  Availability or unavailability of a apartment has nothing to do with hopscore

# %% [markdown]
# # Hypothesis
# price
#
# manager
#
# lat and long
#
#
#
# Number of Images has a big score
#
# quality of images
#
# Discription Writing style,neatness and quality has a huge score
#
# No. of bedroom and bathroom has low significance
#
# Eminitiese provided have high significance
#
# Managers review do not account for much
#
# Street address has +5 percent chance to be a 80 if manager review are not present and number of photo is 6 to 7

# %% [markdown]
# # Loading the Data And Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
color = sns.color_palette()
import sklearn 
from sklearn import preprocessing, cross_validation, svm
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split
from sklearn.metrics import log_loss
from sklearn import *
style.use('ggplot')
# %matplotlib inline
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\sklearn\lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
# C:\Program Files\Anaconda2\lib\site-packages\sklearn\qda.py:4: DeprecationWarning: qda.QDA has been moved to discriminant_analysis.QuadraticDiscriminantAnalysis in 0.17 and will be removed in 0.19.
#   "in 0.17 and will be removed in 0.19.", DeprecationWarning)

# %%
import pandas as pd
df_train = pd.read_json('train.json')

# %%
import pandas as pd
df_test = pd.read_json('test.json')

# %% [markdown]
# # Checking for Missing Data ,random data

# %%
#import missingno as msno
#%matplotlib inline
#msno.matrix(df_train.sample(10000))

#pd.isnull(df_train)

#No NA values

# %% [markdown]
# # Selecting the features

# %%
y=np.array(df_train['interest_level'])

# %%
feature_set = {}
for features in df_train['features']:
    for feature in features:
        feature_set[feature.lower()] = feature_set.get(feature.lower(), 0) + 1
feature_set
# Out:
# {u'photos of actual apartment': 1,
#  u'** extravagant east village! * massive 4br mansion * 2 full baths * gourmet kitchen * roomy closets **': 1,
#  u'complimentary sunday brunch': 3,
#  u'sundeck with bbq grills': 2,
#  u'party room': 8,
#  u'private shuttle': 1,
#  u'spacious layout': 1,
#  u'cable ready': 4,
#  u'private garden': 6,
#  u'recent renovation': 1,
#  u'on-site parking available': 8,
#  u'private-outdoor-space': 22,
#  u'private roof access': 3,
#  u'julian balcony': 1,
#  u'wine cooler': 1,
#  u'granite counter tops': 5,
#  u'built-in breakfast bar': 1,
#  u'decorative fireplace': 27,
#  u'custom lighting': 1,
#  u'move-in coordination': 1,
#  u'new marble bathroom': 1,
#  u'oversized closet': 1,
#  u'** no fee baby! * massive 2br w/terrace * gourmet ss kitchen * elev/lndry bldg * scenic roof deck * 3 blks to train **': 1,
#  u'landlord paying for all utilities! tenant pays for cable / tv / internet.': 1,
#  u'** chic chelsea find! * massive 4br home * 2 full baths * chef inspired kitchen * elev that opens into apt * cats ok **': 1,
#  u'central air': 10,
#  u'storage in building included!': 1,
#  u'full-time doorman': 85,
#  u'laundry facility on every floor': 1,
#  u'large windows w/ lots of natural light': 2,
#  u'oversize terrace': 1,
#  u'dining/living room': 1,
#  u'overlooks garden': 1,
#  u'short term': 3,
#  u'walls of windows': 1,
#  u'3 ac': 1,
#  u'renovated 1 bed': 1,
#  u'** gigantic greenpoint 2br home * room to entertain * extra storage * dining room * all brand new! **': 1,
#  u'walk in closet': 24,
#  u'yoga and spin studios': 2,
#  u'garden': 99,
#  u'fireplaces': 9,
#  u'** sprawling 2br super share * sparkling clean & brite * ss eat-in kitchen * roomy closets * 4 blks to bedford l **': 1,
#  u"** east village extravaganza * massive 2br home * perfect share * cook's kitchen * perfect natural light **": 1,
#  u'marble bathroom': 9,
#  u'** eye popping no fee! * massive 1br home * exposed brick * private terrace * dishwasher * elev bldg * roof deck * pets ok **': 1,
#  u'pets allowed case by case': 1,
#  u'rent stabilize - elevator building': 1,
#  u'furnished price. central air conditioning. high ceilings. stainless steel appliances. fully equipped stainless steel appliances kitchen.': 1,
#  u'mid-rise': 1,
#  u'exposed brick': 113,
#  u'24 hour doorman': 3,
#  u"residents' lounge": 1,
#  u'flex two bed': 1,
#  u'dw  duplex   penthouse': 1,
#  u'** spacious studio supreme * amazing corner layout * tons of sunlight * pets ok **': 1,
#  u'media screening room': 4,
#  u'common backyard': 15,
#  u'fireplace': 919,
#  u"** sprawling 2br super share * massive windows galore * cook's kitchen * 2 blks to bedford l stop **": 1,
#  u'pre-war details': 1,
#  u'incredible views!': 1,
#  u'must see': 1,
#  u'exercise studio': 3,
#  u'washer/dryer in building': 28,
#  u'** brownstone beauty * massive 2br home * steps to the park * ss kitchen * dishwasher * oversized closets * near columbia u **': 1,
#  u'game room': 5,
#  u'manhattan views': 2,
#  u'modern finishes': 1,
#  u'heat hot water included': 2,
#  u'renovated bathroom': 2,
#  u'bright': 4,
#  u'** classy corner studio * oversized & underpriced * windows all around * pets ok **': 1,
#  u'** sprawling true 2br super share * exposed brick * scenic roof deck * pets ok **': 1,
#  u"resident's courtyard": 1,
#  u'subway': 100,
#  u'mail room': 11,
#  u'no broker fee!': 1,
#  u'video access control': 1,
#  u'massive living-room': 1,
#  u'condo finishes': 7,
#  u'laundry in building': 18944,
#  u'flat-screen tv': 1,
#  u'** sprawling 1br w/home office * private backyard * sparkling clean & bright * steps to l train **': 1,
#  u'ft doorman': 28,
#  u'private dining room': 1,
#  u'** massive 3br super share * washer/dryer * ornate prewar details * steps to bedford l stop **': 1,
#  u'* marvelous midtown gem * spacious sundrenched studio * stunning prewar details * cats ok **': 1,
#  u'business center': 22,
#  u'yoga / dance studio': 3,
#  u'storage room': 18,
#  u'$500 security deposit': 1,
#  u'french door': 1,
#  u'\xa0subway': 1,
#  u'roof': 1,
#  u'indoor swimming pool': 3,
#  u'designer finishes': 1,
#  u'a wide array of complimentary fitness classes offered weekly': 1,
#  u'building-common-outdoor-space': 39,
#  u'soaking neptune bathtub': 1,
#  u'700 sf': 1,
#  u'childrens playroom': 74,
#  u'washer in unit': 186,
#  u'$1500. move-in visa giftcard will be handed to new tenants upon rental lease signing': 1,
#  u'** wicked w50s steal! * massive 1br home * hi end renovations * elev/lndry bldg * real pix * steps to the park! **': 1,
#  u'unit has balcony': 1,
#  u'reduced fee while it lasts!': 2,
#  u'tenant pays for electric!': 1,
#  u'small dogs ok': 1,
#  u'water view': 3,
#  u'** w70s winner! * super sweet studio * walls of windows * hi end renovations * oversized closets * steps to the park! **': 1,
#  u'building link notification & key track for tenants convenience': 1,
#  u'valet': 102,
#  u'yoga an pilates class': 1,
#  u'oversized windows': 1,
#  u'mosaic tiled kitchen': 1,
#  u'heat & water included': 1,
#  u'heated lap pool': 1,
#  u'club room': 1,
#  u'new': 1,
#  u'hardwood floors': 23558,
#  u'** sprawling sundrenched studio * mr clean approved * roomy closets * pets ok * w50s ~ steps to the park! **': 1,
#  u'new kitchen!': 1,
#  u'central heat': 2,
#  u'rent stabalized': 3,
#  u'tenant lounge': 9,
#  u'hardwood  floors': 1,
#  u'outdoor terrace': 1,
#  u'rent stabilized': 3,
#  u'park view': 5,
#  u'ss appliances': 3,
#  u'dining area': 1,
#  u'-greal location': 1,
#  u'roof access': 7,
#  u'** entire floor! * sprawling 2br home * immaculate renovations * fireplace * 2 blks to bedford l stop **': 1,
#  u'exposed brick wall': 3,
#  u'nyu': 1,
#  u'private patio!': 1,
#  u'king sized bedroom': 3,
#  u'onsite dry cleaner': 1,
#  u'2 full baths': 2,
#  u'poker table': 2,
#  u'78th & lexington ave': 1,
#  u'at an additional cost.': 1,
#  u'on-site parking lot': 27,
#  u'full service garage': 28,
#  u'** oversized 3br home * sparkling clean * tons of natural light * 2 blks to the waterfront & bedford l stop **': 1,
#  u'ground floor': 1,
#  u'30': 1,
#  u'light.': 1,
#  u'reduced fee': 699,
#  u'double hung wooden shutters': 1,
#  u'** central park steal! * massive studio supreme * gut renovated * walls of windows * elev/lndry bldg **': 1,
#  u'** midtown no fee mansion! * sprawling 2br super share * chef inspired kitchen * elev/lndry bldg **': 1,
#  u'concierge services': 2,
#  u'mint condition': 1,
#  u'convertible 1br': 1,
#  u'owner occupied - 3 family townhouse - no realtor fees - this beautiful apt is offered below market rate': 1,
#  u'water feature': 1,
#  u'brand new renovation': 1,
#  u'on-site garage': 143,
#  u'near transportation': 3,
#  u'private backyard': 20,
#  u'storage unit': 1,
#  u'shuttle service to subway': 1,
#  u'a one-of-a-kind full service luxury highrise': 2,
#  u'brand new washer & dryer': 1,
#  u'newly renovated w/ oak wood floors   mid century modern style interior   large closets in every bedroom extra storage space in hall. large living room': 1,
#  u'private roof deck': 5,
#  u'fully equipped chef\u2019s kitchen with private roof deck': 3,
#  u'loft like': 1,
#  u'diplomats ok': 3,
#  u'however there\'s a standing "no walls\' building policy!': 1,
#  u'washer/dryer hookup': 7,
#  u"** all brand new no fee! * expansive 2br mcmansion * private terrace * cook's ss kitchen * elev/lndry bldg * 3 blks to l train **": 1,
#  u'utilities included': 5,
#  u'1 month free': 4,
#  u'no pets': 70,
#  u'concierge and live-in super.': 1,
#  u'residents can choose from three high-speed internet providers: verizon fios': 1,
#  u'high ceiling': 200,
#  u'tenant pays for only electric!': 1,
#  u'1st': 1,
#  u'brand new stainless steel appliances': 1,
#  u'built in office area': 1,
#  u'** pristine park ave find! * massive 2br triplex dream share * dining rm * elev/lndry bldg * heart of the e50s **': 1,
#  u'third floor walk up': 1,
#  u'everything brand new!': 1,
#  u'onsite super and porter': 1,
#  u'misting shower and resident lounge available.': 2,
#  u'full size gym': 3,
#  u'built in microwave': 2,
#  u'custom painted murals': 1,
#  u'washer and dryer in unit': 1,
#  u'parking garage': 1,
#  u'all utilities included!!': 1,
#  u'washer/dryer in-unit': 5,
#  u'landlord is offering month of april free': 1,
#  u'30th st & madison avenue': 1,
#  u'2 blocks away from union square': 1,
#  u'24hr doorman': 6,
#  u'stunning new renovation': 1,
#  u'lounge spaces': 2,
#  u'parks in area': 1,
#  u'two closets': 1,
#  u'mins from train': 1,
#  u'diswasher': 1,
#  u'highland park': 1,
#  u'lounge room': 44,
#  u'jacuzzi bath tube': 1,
#  u'terraces / balconies': 14,
#  u'alcove': 1,
#  u'half bath': 1,
#  u'bright & sunny!': 1,
#  u'concierge service. fitness center': 1,
#  u'dishwasher': 20806,
#  u'resident super in the building': 1,
#  u'walk-in closet views:': 1,
#  u'sorry no pets': 1,
#  u'personal trainer': 1,
#  u'yard': 4,
#  u'gym discount': 1,
#  u'air conditioning': 38,
#  u'open views': 1,
#  u'on-site attended garage': 3,
#  u'no fee...luxury doorman building^^^river views': 1,
#  u'outdoor entertainment space': 28,
#  u'convertible-2': 1,
#  u'comprehensive valet services including maid service': 1,
#  u'wheelchair ramp': 32,
#  u'lighting upgrades': 1,
#  u'garage parking': 2,
#  u'tall ceilings': 1,
#  u'1.5 marble baths': 1,
#  u'breakfast bar': 7,
#  u'mw': 2,
#  u'low fee listing': 1,
#  u'super on site': 1,
#  u'baruch': 1,
#  u'large finished basement': 1,
#  u'** unique find! * sprawling 2br super share * walls of windows * stunning renovations * 2 blks to bedford l stop **': 1,
#  u'gas stove': 1,
#  u'health club': 29,
#  u'cable/satellite tv': 12,
#  u'24-hour concierge': 1,
#  u'fully-equipped club fitness center': 3,
#  u'nearby medical centers': 1,
#  u'well mainatained swimming pool': 1,
#  u'river view': 2,
#  u'concierge': 166,
#  u'control & pay for your own heat with your own thermostat': 1,
#  u'southern exposure': 4,
#  u'private-balcony': 31,
#  u'** holy deal batman!! * oversized 3br mansion * 2 full baths * huge scenic terrace * doorman * elev/lndry bldg * roof deck * real pix **': 1,
#  u'water views': 2,
#  u'pets: case by case': 1,
#  u'working fireplace': 2,
#  u'live in super': 366,
#  u'low-rise': 1,
#  u'** holy deal batman! * entire floor! * massive 4br mansion * gourmet kitchen * pets ok **': 1,
#  u'** greenpoint giant * huge true 2br mega-share * sparkling clean & brite * steps to the park & bedford l stop **': 1,
#  u'huge & gut renovated': 1,
#  u'tenants lounge with free wi-fi': 1,
#  u'state-of-the-art fitness center': 5,
#  u'stunning renovations': 1,
#  u'** classy conv 2br duplex dream! * room to entertain * lndry bldg * cats ok * heart of the village **': 1,
#  u'huge 1 bedroom': 1,
#  u'near pratt': 1,
#  u'unassigned paid parking available nearby': 3,
#  u'** diamond uws deal! * massive studio * exposed brick * dishwasher * pets ok * steps to the park! **': 1,
#  u'lounge': 83,
#  u'executive conference room with large-screen hdtv': 1,
#  u'granite bathroom': 1,
#  u'** sprawling sundrenched 2br home * no fee! * walls of windows * chef inspired eat-in kitchen * 2 blks to train **': 1,
#  u'** huge true 3br home * mr clean approved * massive windows galore * steps to the park & bedford l stop **': 1,
#  u'brownstone': 25,
#  u'residents lounge': 98,
#  u'amazing deal!': 1,
#  u'** sprawling 2br super share * gut renovated * clean & brite * 1/2 blk to bedford l **': 1,
#  u'part-time doorman': 5,
#  u'absolute value for size & location': 1,
#  u'state of the art fitness center': 1,
#  u'multi-level': 632,
#  u'** sundrenched & spacious * massive 3br home * all modern & new * steps to l train **': 1,
#  u'laundry': 283,
#  u'large private deck': 1,
#  u'a true top luxury hi-rise': 1,
#  u'natural sunlight': 2,
#  u'deco fireplace': 5,
#  u'big open spaces': 1,
#  u'children\u2019s playroom': 5,
#  u'space': 2,
#  u'b billiards table': 1,
#  u'** double duplex deal! * sprawling 3br home * 1.5 baths * private deck & balcony! * eat-in kitchen * washer//dryer * all modern new! **': 1,
#  u'large livingroom': 1,
#  u'recently renovated': 1,
#  u'children playroom': 3,
#  u"** extra sweet east village! * massive 2br home * ornate prewar details * exposed brick * cook's kitchen * pets ok **": 1,
#  u'june 1st occupancy': 1,
#  u'flexible viewing times': 1,
#  u'backyard': 16,
#  u'high-speed internet': 16,
#  u'free health club': 1,
#  u'new construction': 2608,
#  u'king size bedroom': 3,
#  u'open house sat. may 14 12- 1pm': 1,
#  u'available  07/01/16': 1,
#  u'keyed elevator with direct access into your living room': 1,
#  u'full service luxury highrise': 2,
#  u'washer/dryer in bldg': 3,
#  u'wheelchair access': 1358,
#  u'semi-private backyard': 1,
#  u'gym fitness lounge swimming pool sun decks exercise studios indoor half-basketball court': 1,
#  u'** the perfect share * sprawling 3br home * hi end renovations * mr clean approved * roomy closets * g-village baby! **': 1,
#  u'package room': 14,
#  u'an expansive landscaped terrace and sun deck': 1,
#  u'common garden': 16,
#  u'laundry in some units': 2,
#  u'private patio': 2,
#  u'private laundry room on every floor': 8,
#  u'patio': 136,
#  u'gardening area with rentable plots': 3,
#  u'exclusive': 2167,
#  u'junior 1 bedroom layout': 1,
#  u'** pristine prewar gem! * massive 3br super share * gut renovated * chef;s kitchen * elev bldg * pets ok **': 1,
#  u'dogs ok': 1,
#  u'furnished': 690,
#  u'ac central': 1,
#  u'private balcony': 34,
#  u'washer/ dryer in unit': 1,
#  u'large': 1,
#  u'jacuzzi': 7,
#  u'actual photos!': 5,
#  u'terrace': 2313,
#  u'000 square foot exclusive courtyard oasis for via residents': 1,
#  u'on-site parking garage': 1,
#  u'walking distances to restaurants': 1,
#  u'ceiling fans': 1,
#  u'live/work': 44,
#  u'fitness center': 13257,
#  u'4 train is less than 1 block away': 1,
#  u'available  05/15/16    dishwasher': 1,
#  u'air conditioned laundry facility': 1,
#  u'rooftop': 3,
#  u'rooftop deck': 14,
#  u'small dressing-area in front of bathroom': 1,
#  u'duplex': 68,
#  u'sleeping alcove': 1,
#  u'swimming pool': 2730,
#  u'gut renovations': 1,
#  u'wash/dryer': 1,
#  u'convertible 2 bedroom': 1,
#  u'65th/2nd ave': 1,
#  u'2 months free': 1,
#  u'steam room': 4,
#  u'spacious': 5,
#  u'closed circuit television security system': 1,
#  u'sun deck': 1,
#  u'one flight walk up': 1,
#  u'kids playroom': 2,
#  u'granite kitchen': 117,
#  u'no fee hardwood floors': 1,
#  u'post-war': 25,
#  u'wood-burning fireplace': 6,
#  u'** sprawling studio home * dishwasher * exposed brick * gut renovated * pets ok * steps to the park **': 1,
#  u'postwar': 2,
#  u'free brealfast': 1,
#  u'stainless steal appliances': 2,
#  u'over sized windows': 1,
#  u'quiet neighborhood': 1,
#  u'roof/sundeck': 1,
#  u'** one of a kind no fee! * massive 3br mansion * eat-in kitchen * tons of sunlight * 2 blks to train **': 1,
#  u'24/7 concierge': 8,
#  u'** unique union sq steal * massive 1br home * mr clean approved * real pix * elev bldg **': 1,
#  u'1/2 month fee': 1,
#  u'low fee and great space too!': 1,
#  u'open concept kitchen': 1,
#  u'decorative wooden fireplace': 1,
#  u'dogs under 20 lbs.                parking ( additional fee)': 1,
#  u'1 br or conv 2': 1,
#  u'high floor unit': 1,
#  u'private deck': 10,
#  u'windowed kitchen': 2,
#  u'grand central': 2,
#  u'billiards room': 10,
#  u'live-in super': 89,
#  u'soaking tub': 1,
#  u'great area': 2,
#  u'** oversized 2br super share * french doors * ss eat-in kitchen * mr clean approved * heart of midtown! **': 1,
#  u'2nd ave': 1,
#  u'crown molding': 1,
#  u'walls ok': 1,
#  u'fully equipped fitness center with studio for classes': 1,
#  u'park block': 1,
#  u'wifi in resident lounge': 2,
#  u'in-unit washer/dryer': 23,
#  u'attached parking garage': 1,
#  u'55th & 6th ave': 1,
#  u'last': 1,
#  u'huge rooms': 1,
#  u'huge living room': 2,
#  u'offering  1 month free or 1 month op': 1,
#  u'electricity included': 1,
#  u'total reno. heart of west village': 1,
#  u'come live the good life for  less $$$$': 1,
#  u'steps to prospect park': 1,
#  u'bluetooth': 3,
#  u'valet laundry': 3,
#  u'one month free rent': 3,
#  u'market on site': 1,
#  u'** huge true 2br super share * ornate prewar details * so fresh & so clean * l train baby! **': 1,
#  u'air conditioned': 1,
#  u'large room': 1,
#  u'hardwood flooring throughout': 1,
#  u'bridge view': 1,
#  u'voice intercom': 1,
#  u'washer dryer in unit': 1,
#  u'prewar': 1349,
#  u'queen sized rooms': 7,
#  u'transport right outside': 1,
#  u'bbqs!': 1,
#  u'month free': 1,
#  u'previous tenant found easy on-street parking.': 1,
#  u'no fee or one month free': 1,
#  u'large apartment': 1,
#  u'fire place': 2,
#  u'high ceilings.': 1,
#  u'twenty-four-hour concierge and doorman': 1,
#  u'flat screen tv and sound system': 1,
#  u'state-of-the-art swimming pool': 1,
#  u'east and west resident lounges reading room outdoor lounges with river views party room chefs kitchen movie screening room tot spot playroom ping pong': 1,
#  u'washer': 1,
#  u'** oversized & underpriced * classy corner studio * all modern & new * perfect sunlight * pets ok **': 1,
#  u'** pristine townhouse * massive 2br super share * dishwasher * e50s baby! * perfect natural light * roomy closets **': 1,
#  u'24hr doormen': 1,
#  u'**laundry room code is 3401': 1,
#  u'extra room': 4,
#  u'outdoor pool': 12,
#  u'outdoor space': 5270,
#  u'!!!!low fee!!!!': 1,
#  u'rent-stabilized - ** rare **': 1,
#  u'** oversized & underpriced! * sprawling sunfilled studio * roomy closets * tons of sunlight * pets ok **': 1,
#  u"** bring ur bbq! * sprawling 2br home * huge rear terrace * modern everything * chef's kitchen * all new **": 1,
#  u'oak floors': 3,
#  u'recessed lighting.': 2,
#  u'heat included': 2,
#  u'digital tv': 1,
#  u'flex-1': 2,
#  u'flex-2': 13,
#  u'flex-3': 6,
#  u'flex-4': 1,
#  u'washer/ dryer hookups': 1,
#  u'valet service': 4,
#  u'local gym discount': 1,
#  u'large & medium storage': 1,
#  u'wine cooler.': 1,
#  u'double height lobby french limestone and rojo alicante marble': 1,
#  u'12th st & 3rd ave': 1,
#  u"** huge true 3br super share * stunning renovations * walls of windows * cook's kitchen * gorgeous greenwich village **": 1,
#  u'heat/hot water/gas included': 1,
#  u'2 story tenant lounge': 1,
#  u"children's room": 3,
#  u'on site super': 3,
#  u'pets upon approval': 2,
#  u'pre-war charm': 2,
#  u"** midtown east elegance! * massive 1br home * walls of windows * gourmet kitchen * brand spankin' new! **": 1,
#  u"commuter's paradise": 1,
#  u'close to subway - renovated!': 1,
#  u'twenty-four hour concierge and doorman': 2,
#  u'atm': 1,
#  u'fitness room': 5,
#  u'pets: cats only': 1,
#  u'** expansive king-sized 2br mega-share * eat-in kitchen * bike storage * courtyard * 3 blks to bedford l **': 1,
#  u'laundry / dry-cleaning and auto care': 1,
#  u'spacious private garden': 1,
#  u'washer/dryer inside the unit': 1,
#  u'** masterful bklyn find! * sprawling 3br mega-share * gourmet kitchen * mr clean approved * 2 blks to bedford l **': 1,
#  u'full floor': 1,
#  u'pets: cats/small dogs': 4,
#  u'deco brick walls': 1,
#  u'great location': 1,
#  u"** brand spankin' new * oversized 3br home * washer/dryer * ss kitchen w/island * heart of desirable soho **": 1,
#  u'complimentary continental breakfast': 2,
#  u'close to hospitals': 1,
#  u'wood burning fireplace': 1,
#  u'vacation home': 1,
#  u'bbq grill': 1,
#  u'queen sized bedroom': 2,
#  u'000 sf fitness center': 1,
#  u'sunlight': 1,
#  u'complimentary breakfast on weekdays': 1,
#  u'post war': 21,
#  u'seperate kitchen': 1,
#  u'24/7 fitness center': 1,
#  u'short term allowed': 76,
#  u'gatehouse security': 1,
#  u'private roof-deck': 2,
#  u'24-hour attended lobby': 1,
#  u'spacious living room': 1,
#  u'renovated': 337,
#  u'lounge with wifi': 1,
#  u'yoga room': 3,
#  u'perfect location!!!!': 1,
#  u'fireplace storage': 1,
#  u'big 2 bed deal..grab it or grieve it!!!': 1,
#  u'elevator': 26273,
#  u'available  04/15/16': 1,
#  u'2': 1,
#  u'oversized window': 1,
#  u'lease term (flexible) 3 months - 1 year / furnished or unfurnished': 1,
#  u'1200sq ft': 1,
#  u'private lounge w/ wet bar & billiards table': 1,
#  u'hardwood flooring': 2,
#  u'amazing detail': 1,
#  u'garden roof deck': 1,
#  u'electronic keycard': 1,
#  u'hot water inc. huge walk-in closet or extra room!': 1,
#  u'skylight atrium': 3,
#  u'co-op': 1,
#  u'island kitchen': 1,
#  u'and stainless steel appliances with a dishwasher well maintained hardwood floors add to the warmth and modern feel of the space.': 1,
#  u'bicycle storage': 1,
#  u'gramercy park': 2,
#  u'gym': 58,
#  u'new renovation': 5,
#  u'corner unit': 2,
#  u'large open kitchen': 1,
#  u'equal size rooms': 1,
#  u'king bedrooms': 2,
#  u'fully equipped gym': 1,
#  u'\u2022 on-site lifestyle concierge by luxury attach\xe9 \u202224/7 doorman \u2022 state of the art cardiovascular and weight training equipment \u2022 24-hour valet parking garage \u2022 valet services including dry cleaning': 1,
#  u'** oversized & underpriced! * sprawling conv 3br mansion * massive windows galore * elev bldg * steps to the park! **': 1,
#  u'valet parking': 38,
#  u'recreational room': 1,
#  u'3-12 month leases allowed': 1,
#  u'direct bus line to ferry': 1,
#  u'in-unit washer-dryer': 1,
#  u's/s appliances': 6,
#  u'roof deck with real grass': 3,
#  u'new stainless steel appliances': 1,
#  u'9th floor manhattan views': 1,
#  u'stainless steel appliances': 177,
#  u'dog okay': 1,
#  u'walk in closet(s)': 105,
#  u'residents garden': 56,
#  u'steps from tompkins sq park': 1,
#  u'arguably the most well-maintained luxury highrise in the city': 1,
#  u'call/text abraham caro @ 917-373-0862': 4,
#  u'large windows': 2,
#  u'** holy no fee deal! * oversized 2br super share * private terrace * ss kitchen * dishwasher * elev/lndry bldg * 3 blks to l train **': 1,
#  u'on-sites super': 1,
#  u'light': 146,
#  u'25lb weight limit on pet': 1,
#  u'share ok': 2,
#  u'bicycle room and individual resident storage': 1,
#  u'true 2 bedroom - on lexington ave': 1,
#  u'indoor pool': 48,
#  u'duplex layout': 1,
#  u'counter-top space': 1,
#  u'screening room': 12,
#  u'club sun deck has spectacular city and river views': 3,
#  u'pets allowed': 15,
#  u'redwood hardwood floor': 1,
#  u'2 bathrooms': 1,
#  u'gym in building': 10,
#  u'** sprawling sunfilled 1br home * unique prewar details * gourmet kitchen * heart of midtown! **': 1,
#  u'common balcony': 1,
#  u'bicycle and tenant st...orage available for rent': 1,
#  u'bluetooth system': 1,
#  u'full kitchen': 1,
#  u'storage in basement': 1,
#  u'standard on-site parking': 1,
#  u'on-site lifestyle concierge by luxury attach\xe9': 3,
#  u'no fee specialist! harry ego 718.413.8270 hego@citihabitats.com': 1,
#  u'cinema room': 7,
#  u'xxl windows': 1,
#  u'accepts credit cards (fee applies)': 1,
#  u'mint': 2,
#  u'all kitchen appliances included': 1,
#  u'open granite kitchen': 1,
#  u'over sized apartment': 1,
#  u'available  05/01/16      swimming pool         dishwasher': 1,
#  u'heat and water included in rent': 1,
#  u'exclusive rental': 1,
#  u'basement storage': 25,
#  u'state-of-the-art cardio and fitness club': 2,
#  u'two level fitness center': 1,
#  u'landmark building': 1,
#  u'updated kitchen and bathroom': 1,
#  u'** huge true 2br super share * exposed brick * gourmet kitchen * lndry bldg * heart of the village **': 1,
#  u'laundry in bldg': 1,
#  u'free month & no-fee': 1,
#  u'children\u2019s playroom.': 1,
#  u'24 hour attended lobby': 1,
#  u'5 bed': 1,
#  u'east village': 1,
#  u'outdoor bbqs': 3,
#  u'furnished wrap around terrace': 1,
#  u'newly renovated': 160,
#  u'real wall allowed': 1,
#  u'new reno': 1,
#  u'87th & 1st': 1,
#  u'pet friendly': 20,
#  u'one month fee': 2,
#  u'boating hardwood floors': 1,
#  u'media room': 8,
#  u'skyline view': 2,
#  u'4 roof-decks with river views': 1,
#  u'24th st & 3rd ave': 1,
#  u'** classy clinton home * massive 1br * gourmet kitchen * exposed brick * roomy closets **': 1,
#  u'** pristine modern townhouse! * massive 2br home * chef inspired kitchen * huge windows galore * cats ok **': 1,
#  u'resident events': 1,
#  u'large windows w/ natural light': 1,
#  u'sun drenched': 2,
#  u'4th off charles': 1,
#  u'window bathroom': 1,
#  u'in unit washer and dryer': 4,
#  u'billiards and shuffle board game room poker room golf simulator and putting green': 1,
#  u'no board approval': 1,
#  u'washer dryer': 1,
#  u'on-site management': 1,
#  u'fios high speed internet': 1,
#  u'premier resident services offered by our friendly and helpful staff': 1,
#  u'no fee!!!': 2,
#  u'central a/c': 63,
#  u'continental breakfast served 5 days a week': 1,
#  u'stainless steet appliances': 1,
#  u'closet space': 2,
#  u'fitness facility': 3,
#  u"children's playroom": 41,
#  u'great views': 1,
#  u'lots of light': 1,
#  u'high ceilings': 613,
#  u'tons of natural light': 7,
#  u'lexington 95th': 1,
#  u'500 sq ft': 1,
#  u'common parking/garage': 91,
#  u'** w60s wonder ~ near the park! * overszed studio steal * courtyard * free gym * elev/lndry bldg * cats ok **': 1,
#  u"** oversized 2br super share * chef's kitchen * exposed brick * lndry bldg * heart of the village **": 1,
#  u'mullion pane windows': 1,
#  u'live-in superintendent': 118,
#  u'walk-up': 4,
#  u'ceiling fan': 1,
#  u'floor-to-ceiling windows': 1,
#  u'outdoor space (private roof deck)': 1,
#  u"two en-suite balcony's.": 1,
#  u'updated appliances': 1,
#  u'private outdoor space': 534,
#  u'** oversized & underpriced!! * sprawling sunfilled studio * gourmet kitchen * gut renovated * w50s ~ near central park! **': 1,
#  u'one month rent free concession on a 12 month lease': 1,
#  u'bike room': 114,
#  u'huge closets': 1,
#  u'** sprawling true 3br super share * fit for kings! * unique renovations * steps to the waterfront * 1 blk to bedford l stop **': 1,
#  u'** oversized 1br home * gut renovated * perfect natural light * heart of chelsea * pets ok **': 1,
#  u'gas and electric included in rent': 1,
#  u'city view': 7,
#  u'pre-war small dogs': 1,
#  u'no fee!!!roof deck': 1,
#  u'tenant storage': 2,
#  u'satellite tv': 1,
#  u'concierge service': 20,
#  u'indoor parking': 1,
#  u'attached garage': 1,
#  u'chefs kitchen': 7,
#  u'telephonic intercom system/multiple phone lines per residence': 1,
#  u'modern kitchen': 1,
#  u'queen size sleeping alcove': 1,
#  u'deck': 20,
#  u'3': 1,
#  u'package service': 4,
#  u'laundry.': 1,
#  u'custom murals on the ceiling and living room wall. painted my a local artist.': 1,
#  u'shuttle service': 1,
#  u'outdoor grilling terrace': 1,
#  u'huge walk in closet': 1,
#  u'rooftop sundeck': 1,
#  u'housekeeping service': 5,
#  u'dish washer': 2,
#  u'sundeck': 9,
#  u'** e60s excellence * sprawling 1br home * gourmet kitchen * windows all around * pets ok **': 1,
#  u'ample closet space': 1,
#  u'1100 sq ft': 1,
#  u'large closets': 1,
#  u'dry-cleaning service': 1,
#  u'green building': 247,
#  u'the friendliest doormen in all of manhattan': 1,
#  u'storage facilities available': 5,
#  u'guarantors accepted': 16,
#  u'sunny': 2,
#  u'wardrobe style closets': 1,
#  u'24/7 doorman concierge': 5,
#  u'on-site super': 32,
#  u'gut renovated.': 1,
#  u'madison square park': 1,
#  u'free cable tv and wireless internet': 1,
#  u'great share': 1,
#  u'dw': 3,
#  u'washer/dryer in unit': 11,
#  u'near all trains': 1,
#  u'24-hour parking garage with an electric vehicle charging station.': 1,
#  u'electronic rent payment (ach)': 1,
#  u"** rent stabilized * oversized 1br home * mr clean approved * separate cook's kitchen * heart of midtown **": 1,
#  u'brand newm outdoor deck': 1,
#  u'hi rise': 23,
#  u'two full bathrooms': 1,
#  u'abundant closets': 1,
#  u'indoor 50ft lap pool; dishwasher; free bike storage': 1,
#  u'new electric': 1,
#  u'european air condition in each room': 1,
#  u'spa center': 1,
#  u'bike storage': 13,
#  u'36th st & 3rd ave': 1,
#  u'massive home': 1,
#  u'furnished rental': 1,
#  u'oversized': 1,
#  u'storage locker for each apt': 1,
#  u'w/d': 1,
#  u'central park 1/2 block away!': 1,
#  u"lot's of light": 1,
#  u'top floor unit': 1,
#  u'leed certificate gold': 1,
#  u'view': 60,
#  u'stainless steel full size appliances.': 1,
#  u'close to nyc': 1,
#  u'expansive sundeck': 2,
#  u'publicoutdoor': 423,
#  u'gut renovated': 9,
#  u'spacious rooms': 1,
#  u'hardwood': 1058,
#  u'** modern village marvel * sprawling 2br home * exposed brick * lndry bldg * near the park **': 1,
#  u'available 06/01/16': 1,
#  u"** bklyn's finest! * massive true 2br * courtyard * fully renovated * 2 blks to bedford l stop **": 1,
#  u'rooftop terrace': 16,
#  u'shared backyard': 11,
#  u'** real no fee baby! * expansive 3br masterpiece * spacious & sunfilled * sparkling clean * eat-in kitchen * 2 blks to train **': 1,
#  u'club room w billiards tables': 1,
#  u'great views of the neighborhood': 1,
#  u'private parking': 16,
#  u'parking': 88,
#  u'** w70s winner! * oversized 3br duplex mansion * 2 full baths * private roof deck * dishwasher * steps to the park **': 1,
#  u'security ******available june 1st***': 1,
#  u'community recreation facilities': 13,
#  u'one small dog ok on approval': 2,
#  u'nearby m & r trains': 1,
#  u'** oversized 1br home * huge windows galore * washer/dryer * rent stabilized! * off 6th ave ~ heart of midtown! **': 1,
#  u'** heart of the village! * massive 3br super share * mr clean approved * ornate prewar details * gourmet kitchen * tons of sunlight **': 1,
#  u'laundry room on every floor. health club': 2,
#  u'well-maintained': 1,
#  u'a full service luxury residence': 1,
#  u'actual photos': 1,
#  u'50 ft. exercise pool and whirlpool with lifeguard on duty': 1,
#  u"** real no fee luxury! * oversized 2br home ~ fit for queens!! *  chef's kitchen * walls of windows * 1 blk to train **": 1,
#  u'gas included': 3,
#  u'nmw': 1,
#  u'** modern marvel! * heart of the village * oversized 2br home * exposed brick * lndry bldg **': 1,
#  u'guarantors okay': 1,
#  u'laundry & housekeeping \u2022 marc club includes a cinema room': 1,
#  u'great natural light': 1,
#  u'walk-in-closet': 1,
#  u'pets': 7,
#  u"** uptown's best deal! * steps to the park! * massive 1br home * mr clean approved * roomy closets **": 1,
#  u'washer & dryer': 36,
#  u'full skyline view': 1,
#  u'recessed lights': 1,
#  u'cold storage': 5,
#  u'on-site atm machine': 5,
#  u'gramercy': 1,
#  u'shares okay': 1,
#  u'parquet floors': 1,
#  u'washer/dyer combo': 1,
#  u'renovated kitchen': 5,
#  u'plus 1 month free!!!': 1,
#  u'triplex': 3,
#  u'courtyard': 34,
#  u'** diamond no fee deal! * sprawling sunfilled 2br w/private terrace * ss kitchen * elev/lndry bldg * 3 blks to l train **': 1,
#  u'childrens room': 1,
#  u'broker fee.': 1,
#  u'arched doorways': 1,
#  u'valet and dry cleaning services': 1,
#  u'roof grilling area': 3,
#  u'roof deck': 6555,
#  u'exposed brickhardwood floors microwaverenovated open view excellent': 1,
#  u'no application fee!': 1,
#  u'in unit washer & dryer': 1,
#  u'easy qualification': 1,
#  u'all new': 2,
#  u'easy to show!': 1,
#  u'6 bedrooms': 1,
#  u'wi-fi access': 3,
#  u'22': 1,
#  u'restaurant': 1,
#  u'chelsea': 1,
#  u'** the perfect share! * sprawling sunfilled 4br mansion * clean & brite * steps to the park & bedford l stop **': 1,
#  u'quiet': 1,
#  u'000 sq. ft. landscaped terrace complete with an organic garden': 1,
#  u'storage space': 5,
#  u'** court square gem! * sprawling sundrenched 2br home * custom finishes * dishwasher * fireplaces * eat-in kitchen * bay windows **': 1,
#  u'window bath': 3,
#  u'private entrances': 1,
#  u'cats on approval': 1,
#  u'underground parking': 4,
#  u'very comfortable layout': 1,
#  u'balconies in both bedrooms': 2,
#  u'convertible 2': 1,
#  u'near subway': 1,
#  u'common terrace': 22,
#  u'** massive 1br home * rent stabilized * separate kitchen * walls of windows * roomy closets **': 1,
#  u'no fee!': 3,
#  u'leed certified': 4,
#  u'half floor through': 1,
#  u'skylights': 3,
#  u'air condition': 1,
#  u'spin room': 1,
#  u'brand spanking new': 1,
#  u'private roofdeck': 5,
#  u'golf simulator': 1,
#  u'** holy no fee deal batman! * oversized 2br home * sparkling clean & brite * heart of greenpoint * near the park & trains **': 1,
#  u'common courtyard': 1,
#  u'shares ok': 33,
#  u'townhouse': 4,
#  u'four barbecue grills': 1,
#  u'wifi access': 81,
#  u'laundry in bldg.': 1,
#  u'act fast will not last': 1,
#  u'citi bike station': 1,
#  u'no broker fee': 1,
#  u'package receiving': 1,
#  u'laundry & housekeeping': 8,
#  u'in-unit washer & dryer': 1,
#  u'** midtown mansion * huge 2br home * eat-in kitchen * ss appl * french doors * roomy closets **': 1,
#  u'own entrance': 1,
#  u'solarium': 1,
#  u'valet services': 9,
#  u'laundry in unit': 9435,
#  u'union square': 2,
#  u'free gym': 3,
#  u'** murray hill no fee mansion * sprawling 1br home * ornate prewar details * gourmet kitchen * windows all around **': 1,
#  u"** greenpoint giant * sprawling 2br home * chef's kitchen * perfect natural light * steps to the park & train! **": 1,
#  u'** super sweet studio * no fee * dishwasher * roomy closets * elev bldg * pets ok **': 1,
#  u'attached parking': 1,
#  u'exposed brick walls': 1,
#  u'specific dog breeds up to 40lbs': 1,
#  u'fitness center and health club': 1,
#  u'attended garage': 1,
#  u'huge': 3,
#  u'separate kitchen': 5,
#  u'large living room & bedrooms': 1,
#  u'on-site resident manager': 2,
#  u'ceiling-fan...': 1,
#  u'convinient to all major transportation': 3,
#  u'loft': 2101,
#  u'$250 security deposit': 1,
#  u'private storage': 4,
#  u'<null>': 2,
#  u'** the perfect share! * huge true 3br home * gourmet kitchen * tons of natural light * 2 blks to waterfront & bedford l stop **': 1,
#  u'brand new ss appliances': 1,
#  u'pets on approval': 107,
#  u'built-in speaker system': 2,
#  u'rent stabilize': 1,
#  u'electric included': 1,
#  u'garage parking!': 1,
#  u'double panned sound-proof windows /renovated open kitchen marble and stainless steel countertops': 1,
#  u'unassigned paid parking available': 2,
#  u'large private terrace': 1,
#  u'state-of-the-art fitness center and even an on-site dog run': 1,
#  u'fully  equipped': 5,
#  u'dishwasher/microwave': 1,
#  u'sublet': 21,
#  u'available 05/01/16': 2,
#  u'** sassy soho steal! * no fee! * sprawling studio home * gourmet kitchen * huge closets * elev bldg **': 1,
#  u'gut renovation': 1,
#  u'time warner': 1,
#  u'super bright': 1,
#  u'housekeeping + dry cleaning services': 1,
#  u'luxury building': 59,
#  u'2 bedroon convertible': 1,
#  u'multi level': 3,
#  u'kids play room': 1,
#  u'polished hardwood floors': 1,
#  u'midrise': 21,
#  u'1.5 bath': 1,
#  u'finished basement': 3,
#  u'prime location': 1,
#  u'pre war': 3,
#  u'health club with pool on the top floor': 2,
#  u'granite counters': 3,
#  u'penthouse': 5,
#  u'& atm machine on-site': 1,
#  u'** super sweet 1br home * elegant e60s! * mr clean approved * chef inspired kitchen * tons of natural light! * cats ok **': 1,
#  u'laundry on every floor': 3,
#  u'laundry in building!': 1,
#  u'central ac': 17,
#  u'on site dog park and pet spa': 1,
#  u'act fast wont last': 1,
#  u'all common areas feature wi-fi accessibility': 1,
#  u'elevator building': 2,
#  u'lounge w/ free wifi': 1,
#  u'low fee': 4,
#  u'expansive living-room': 1,
#  u'closets': 2,
#  u'rent is net effective-gross price is $3250': 1,
#  u'30th & 3rd ave': 1,
#  u'doorman': 20967,
#  u'pet grooming room': 3,
#  u'southern facing': 1,
#  u'** oversized 3br super share * equal sized brs! * wall of windows * washer/dryer * steps to bedford l stop **': 1,
#  u'full-service condominium': 2,
#  u"1 mo broker's fee 18 mo lease": 1,
#  u'gym/fitness': 115,
#  u'built in ac': 1,
#  u'electronic rent payment': 2,
#  u'views': 1,
#  u'** expansive 4br duplex dream share * garden! * huge windows galore * ornate prewar details * 2 blks to bedford l **': 1,
#  u'laundry hookup': 1,
#  u'** no broker fee! * massive 2br super share * eat-in kitchen * private terrace * elev/lndry bldg * 1 blk to l train **': 1,
#  u'high speed internet': 4299,
#  u'king-sized bedroom': 1,
#  u'large living area': 1,
#  u'sunny southern exposure': 2,
#  u"no broker's fees": 1,
#  u'and rcn': 1,
#  u'outstanding shopping': 3,
#  u'indoor garage available': 1,
#  u'near nqrmg trains': 1,
#  u'closets galore!': 7,
#  u'game center': 1,
#  u'and breathtaking views of new york city from our rooftop terrace': 1,
#  u'parking available': 7,
#  u'** riverside no fee special! * sprawling 1br home * fireplace * bay windows * exposed brick * dishwasher * lndry bldg **': 1,
#  u'window treatments': 1,
#  u'brand new stainless steal appliances!': 1,
#  u'queen & king size bedrooms': 1,
#  u'new stainless appliances': 1,
#  u'sauna': 36,
#  u'bay windows': 1,
#  u'laundry room': 724,
#  u'** the perfect share! * massive 2br home * gut renovated * lndry bldg * pets ok * heart of the village **': 1,
#  u'combo washer dryer': 1,
#  u'attended garage and service entrance': 1,
#  u'** sprawling 3br super share * clean & brite * near waterfront! * 2 blks to bedford l stop **': 1,
#  u'natural light': 3,
#  u'limited time - no fee': 1,
#  u'citibikes nearby': 1,
#  u'rooftop access': 1,
#  u'73rd st.': 1,
#  u'washer/dryer': 133,
#  u'1 month free rent': 1,
#  u'garage attached': 2,
#  u'** elegant e50s!! * sprawling sundrenched 2br home * french drs * breakfast bar * dishwasher * eat-in kitchen * walk-in closets! **': 1,
#  u'huge balcony': 1,
#  u'close to transit': 2,
#  u'xxlarge studio': 1,
#  u'exclusive residential lounge & caf\xe9 \u2022 spacious and breathtaking fully landscaped 10': 1,
#  u'only 1st and security**heat and hot water included**no fee**732-330-4737': 1,
#  u'** no fee multi-level mansion! * massive 3br triplex * huge private terrace * e50s & park ave * elev/lndry bldg **': 1,
#  u'private garage available': 1,
#  u'garbage disposal': 7,
#  u'south facing': 1,
#  u'sleep loft': 1,
#  u'foyer': 2,
#  u'renovated apt': 1,
#  u'a/c units': 1,
#  u'social lounge': 1,
#  u'original details': 3,
#  u'bright spacious 2 br/1ba': 1,
#  u'lowrise': 789,
#  u'000-square foot sun deck\u2022 free wifi in marc club': 1,
#  u'a full service luxury highrise': 6,
#  u'** rare find! * huge true 2br * courtyard * fully renovated * eat-in kitchen * 2 blks to bedford l **': 1,
#  u'common areas': 1,
#  u'** lex ave luxury! * sprawling sunfilled 1br home * all utilities incl! * doorman * elev/lndry bldg * cats ok **': 1,
#  u'magnificent venetian-style': 5,
#  u'** oversized & underpriced no fee * huge 2br home * all modern & new * eat-in kitchen * 2 blks to the train **': 1,
#  u'stainless steel kitchen': 2,
#  u'original molding details': 1,
#  u'no fee!!': 1,
#  u'extra closet space': 2,
#  u'stunning roof deck with breathtaking views': 3,
#  u"** holy no fee deal batman! * massive 1br home * chef's kitchen * magic eraser clean * pets ok * real pix **": 1,
#  u'party/meeting room': 1,
#  u'** diamond no fee deal! * massive 1br w/ home office * condo quality finishes * eat-in kitchen * 1 blk to the park **': 1,
#  u'huge room': 2,
#  u"** rare find! * huge true 2br super share * chef's kitchen * courtyard! * 2 blks to bedford l stop **": 1,
#  u's-steel appliances': 1,
#  u'the most sought after location': 1,
#  u'elevator/laundry/ so close to the 6 $2450!!': 1,
#  u'stainless steel': 6,
#  u'2 beautifully furnished outside sundecks': 1,
#  u'cold storage in lobby': 1,
#  u'conv. 3 bedroom': 1,
#  u'jr.1 bed': 1,
#  u'4': 1,
#  u'spotless laundry': 1,
#  u'laundry in basement': 1,
#  u'queen size bedrooms': 2,
#  u'virtual dm': 1,
#  u'24 hr doorman': 3,
#  u'high-speed internet access': 1,
#  u'close to subway': 7,
#  u'custom window treatments': 1,
#  ...}

# %%
top_features = [(key, value) for key, value in feature_set.items() if value >= 100]

# %% [markdown]
# # assign top features to the values 1 and 0 if pressent in the df_train

# %%
?????????

# %%
x = np.array(df_train)

# %%
df_train["num_photos"] = df_train["photos"].apply(len)
df_train["num_features"] = df_train["features"].apply(len)
df_train["num_description_words"] = df_train["description"].apply(lambda x: len(x.split(" ")))
df_train["created"] = pd.to_datetime(df_train["created"])
df_train["created_year"] = df_train["created"].dt.year
df_train["created_month"] = df_train["created"].dt.month
df_train["created_day"] = df_train["created"].dt.day

features_to_use = ["bathrooms", "bedrooms", "latitude", "longitude", "price",
                   "num_photos", "num_features", "num_description_words",
                   "created_year", "created_month", "created_day"]

# %% [markdown]
#  Later we will try to add value to features and description words

# %%
X = df_train[features_to_use]
y = df_train["interest_level"]
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33)

# %%
X=preprocessing.scale(X)

# %%
#y = pd.get_dummies(df_train['interest_level'])

# %%
df_boost = df_train[['interest_level','latitude','longitude','bathrooms','bedrooms','price','num_photos','num_features','num_description_words','created_year','created_month','created_day']]

# %%
df_boost
# Out:
#        interest_level  latitude  longitude  bathrooms  bedrooms  price  \
# 10             medium   40.7145   -73.9425        1.5         3   3000
# 10000             low   40.7947   -73.9667        1.0         2   5465
# 100004           high   40.7388   -74.0018        1.0         1   2850
# 100007            low   40.7539   -73.9677        1.0         1   3275
# 100013            low   40.8241   -73.9493        1.0         4   3350
# 100014         medium   40.7429   -74.0028        2.0         4   7995
# 100016            low   40.8012   -73.9660        1.0         2   3600
# 100020            low   40.7427   -73.9957        2.0         1   5645
# 100026         medium   40.8234   -73.9457        1.0         1   1725
# 100027            low   40.7278   -73.9808        2.0         4   5800
# 100030            low   40.7769   -73.9467        1.0         0   1950
# 10004             low   40.8448   -73.9396        1.0         1   1675
# 100044           high   40.7488   -73.9770        1.0         2   3000
# 100048            low   40.7707   -73.9817        2.0         2   6895
# 10005             low   40.7584   -73.9648        1.0         1   3050
# 100051         medium   40.7439   -73.9743        1.0         0   2350
# 100052            low   40.7305   -73.9830        1.0         2   3650
# 100053            low   40.8643   -73.9280        1.0         1   1695
# 100055            low   40.7999   -73.9638        1.0         4   5000
# 100058            low   40.7328   -73.9799        1.0         1   3973
# 100062            low   40.7454   -73.9845        1.0         3   4395
# 100063         medium   40.7427   -73.9794        1.0         2   2999
# 100065            low   40.7447   -73.9741        1.0         1   2595
# 100066            low   40.7074   -74.0081        1.0         1   3695
# 10007          medium   40.7391   -73.9936        2.0         4   7400
# 100071            low   40.7584   -73.9653        3.5         4   7500
# 100075         medium   40.7728   -73.9502        1.0         1   2295
# 100076            low   40.7709   -73.9917        1.0         1   3164
# 100079           high   40.8335   -73.9141        1.0         1   1350
# 100081            low   40.7716   -73.9506        2.0         2   5600
# ...               ...       ...        ...        ...       ...    ...
# 99915             low   40.7176   -73.9531        1.0         1   3126
# 99917             low   40.7655   -73.9785        1.0         1   3325
# 99919          medium   40.7721   -73.9539        1.0         0   2100
# 99921          medium   40.6182   -74.0360        1.0         2   3500
# 99923             low   40.7829   -73.9731        2.0         2  11950
# 99924             low   40.7637   -73.9847        1.0         1   2980
# 99931             low   40.7293   -73.9987        1.0         1   2850
# 99933             low   40.7075   -74.0043        1.0         2   2885
# 99935             low   40.7287   -73.9808        1.0         1   2950
# 99937             low   40.7769   -73.9467        1.5         0   2650
# 9994              low   40.7957   -73.9705        1.0         2   4850
# 99953             low   40.7655   -73.9785        1.0         1   3475
# 99956             low   40.7095   -74.0084        2.0         2   5815
# 99960          medium   40.7179   -73.9989        1.0         1   2050
# 99961             low   40.7222   -73.9824        2.0         3   4600
# 99964          medium   40.7708   -73.9525        1.0         0   2000
# 99965             low   40.7766   -73.9463        2.0         3   9200
# 99966             low   40.7695   -73.9603        1.0         3   4550
# 99979             low   40.6865   -73.9134        1.0         1   1900
# 99980             low   40.7090   -74.0105        1.0         0   2500
# 99982            high   40.7645   -73.9840        1.0         1   2500
# 99984             low   40.7728   -73.9591        1.0         1   2675
# 99986             low   40.7350   -74.0007        1.0         1   3645
# 99987             low   40.7889   -73.9719        1.0         1   2179
# 99988          medium   40.7296   -73.9869        1.0         1   4500
# 9999           medium   40.7426   -73.9790        1.0         2   3200
# 99991             low   40.7102   -74.0163        1.0         1   3950
# 99992             low   40.7601   -73.9900        1.0         1   2595
# 99993             low   40.7066   -74.0101        1.0         0   3350
# 99994             low   40.8699   -73.9172        1.0         2   2200
#
#         num_photos  num_features  num_description_words  created_year  \
# 10               5             0                     95          2016
# 10000           11             5                      9          2016
# 100004           8             4                     94          2016
# 100007           3             2                     80          2016
# 100013           3             1                     68          2016
# 100014           5             0                      9          2016
# 100016          10             8                     87          2016
# 100020           5             8                    134          2016
# 100026           5             4                      4          2016
# 100027           9             2                    166          2016
# 100030           1             0                     28          2016
# 10004            5             7                    105          2016
# 100044           4             4                    108          2016
# 100048           6             6                     76          2016
# 10005            6             5                     86          2016
# 100051           2             5                     70          2016
# 100052           5             1                     49          2016
# 100053           8             5                    172          2016
# 100055           0             3                      9          2016
# 100058          32             2                      9          2016
# 100062           6             4                    143          2016
# 100063           5             9                     43          2016
# 100065           0             2                      9          2016
# 100066           4            10                    112          2016
# 10007            6            12                    137          2016
# 100071           7            12                    118          2016
# 100075           6             3                     63          2016
# 100076           6             8                    106          2016
# 100079           1             0                     35          2016
# 100081           1             8                     51          2016
# ...            ...           ...                    ...           ...
# 99915            6             5                     79          2016
# 99917            9             5                      1          2016
# 99919            4             8                    108          2016
# 99921            6             2                     70          2016
# 99923            2             4                     80          2016
# 99924            3             6                     90          2016
# 99931            3             2                     26          2016
# 99933            4            12                     91          2016
# 99935            4             0                    105          2016
# 99937            7             5                     39          2016
# 9994             8             4                     84          2016
# 99953            1             7                    187          2016
# 99956            8             5                     52          2016
# 99960            3             1                     63          2016
# 99961            8             6                     99          2016
# 99964            3             4                     98          2016
# 99965            4             9                    102          2016
# 99966            4             9                    122          2016
# 99979            0             0                      9          2016
# 99980            4             7                     81          2016
# 99982            3            10                    117          2016
# 99984            4             5                     56          2016
# 99986            5             2                     40          2016
# 99987            8             1                    108          2016
# 99988            8            10                     45          2016
# 9999             4             6                    115          2016
# 99991            8             8                    191          2016
# 99992            3             5                     84          2016
# 99993            9             5                     99          2016
# 99994            7             1                    133          2016
#
#         created_month  created_day
# 10                  6           24
# 10000               6           12
# 100004              4           17
# 100007              4           18
# 100013              4           28
# 100014              4           19
# 100016              4           27
# 100020              4           13
# 100026              4           20
# 100027              4            2
# 100030              4           14
# 10004               6            3
# 100044              4           19
# 100048              4            9
# 10005               6            1
# 100051              4           18
# 100052              4           22
# 100053              4           19
# 100055              4           20
# 100058              4            9
# 100062              4           12
# 100063              4            7
# 100065              4           13
# 100066              4           17
# 10007               6            7
# 100071              4           27
# 100075              4           25
# 100076              4           22
# 100079              4           21
# 100081              4           26
# ...               ...          ...
# 99915               4           25
# 99917               4           26
# 99919               4            8
# 99921               4           29
# 99923               4            5
# 99924               4           24
# 99931               4           25
# 99933               4            3
# 99935               4           19
# 99937               4           14
# 9994                6            6
# 99953               4           26
# 99956               4           16
# 99960               4            5
# 99961               4           22
# 99964               4           29
# 99965               4            3
# 99966               4           15
# 99979               4           14
# 99980               4           27
# 99982               4            7
# 99984               4            2
# 99986               4           14
# 99987               4           11
# 99988               4           22
# 9999                6            2
# 99991               4            4
# 99992               4           16
# 99993               4            8
# 99994               4           12
#
# [49352 rows x 12 columns]

# %%
df_boost_csv = df_boost.to_csv('model1.csv')

# %% [markdown]
# <img src="importance.png">
